# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def show_image(img):
    img = cv2.imread(img)
    plt.axis('off')
    plt.imshow(img)

# %%
show_image('dog.jpeg')

# %%
def save_image(img, filename):
    cv2.imwrite(filename, img)

# %%
img = cv2.imread('dog.jpeg')

# %%
plt.imshow(img)

# %%
def contrast_brightness(img, alpha=1.0, beta=0):
    table = np.array([alpha*i + beta for i in np.arange(0, 256)]).clip(0, 255).astype('uint8')
    return cv2.LUT(img, table)

# %%
adjusted_img = contrast_brightness(img, 1.3, -10)

# %%
plt.imshow(adjusted_img)

# %%
def  saturation(img, satur_coef=1.0):
    img_HSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    img_HSV[:, :, 1] = img_HSV[:, :, 1] * satur_coef
    return cv2.cvtColor(img_HSV, cv2.COLOR_HSV2BGR)

# %%
plt.imshow(saturation(img, 0.5))

# %%
plt.imshow(cv2.resize(img, (1920, 1080)))

# %%
def clip_img(img, x, y):
    return img[x[0]:x[1], y[0]:y[1]]

# %%
plt.imshow(clip_img(img, (50,400), (250,600)))

# %%
def rotate_img(img, degree):
    degree_map = {90: 0, 180: 1, 270:2}
    return cv2.rotate(img, degree_map[degree])

# %%
plt.imshow(rotate_img(img, 90))
